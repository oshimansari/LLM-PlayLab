# %% [markdown]
# <a href="https://colab.research.google.com/github/oshimansari/LLM-PlayLab/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# python program for recursive fibonacci

# %%
def fibonacci(n):
    if n <= 0:
       return "Invalid input"
    elif n == 1:
        return 0
    elif n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)
# Input from user
terms = int(input("Enter the number of terms: "))
print("fibonacci sequence:")
for i in range(1, terms + 1):
    print(fibonacci(i), end=" ")
# Out:
# Enter the number of terms: 7
# fibonacci sequence:
# 0 1 1 2 3 5 8
