# %% [markdown]
# <a href="https://colab.research.google.com/github/oshimansari/LLM-PlayLab/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# python program for Custom exception examples

# %%
class InvalidAgeError(Exception):
    """Custom exception for invalid age"""
    pass
try:
    age = int(input("Enter your age: "))
    if age < 18:
        raise InvalidAgeError("Age must be 18 or above.")
    print("You are eligible.")
except InvalidAgeError as e:
    print("Custom Exception:", e)
except ValueError:
    print("please enter a valid number.")
# Out:
# Enter your age: 16
# Custom Exception: Age must be 18 or above.
