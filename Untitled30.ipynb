# %% [markdown]
# <a href="https://colab.research.google.com/github/oshimansari/LLM-PlayLab/blob/main/Untitled30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# python program to read a file and count words

# %%
filename = input("Enter the file name: ")
try:
   with open(filename, 'r') as file:
       content = file.read()
       words = content.split()
       word_count = len(words)
       print(f"Number of words in the file: {word_count}")
except FileNotFoundError:
   print(f"File '{filename}' not found.")
except Exception as e:
   print(f"An error occurred: {e}")
# Out:
# Enter the file name: python is easy to learn
# File 'python is easy to learn' not found.
